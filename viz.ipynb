# %%
import matplotlib.pyplot as plt

# %%
def plot_one(fname, name=''):
    with open(fname, 'r') as f:
        lines = f.read()
    lines = lines.split('\n')[:-1]
    tokens,losses = [],[]

    for line in lines:
        loss,step,token,time = line.split(',')
        losses.append(float(loss))
        tokens.append(float(token))

    plt.plot(tokens,losses, label=name)

HOME = 'pretrained/snapshot_rw/optc/'
plot_one(f'{HOME}/trw_bertlog_med.txt', name='Medium')
plot_one(f'{HOME}/trw_bertlog_mini.txt', name='Mini')
plot_one(f'{HOME}/trw_bertlog_tiny.txt', name='Tiny')


plt.legend()
plt.show()
