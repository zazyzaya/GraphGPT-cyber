# %%
import torch
import matplotlib.pyplot as plt

# %%
embs = torch.load('t_embs.pt', weights_only=True)

def viz(idx):
    emb = embs[:, idx]
    plt.plot(torch.arange(emb.size(0)), emb)
    plt.show()

[viz(i) for i in range(10)]
# Out:
# [None, None, None, None, None, None, None, None, None, None]
